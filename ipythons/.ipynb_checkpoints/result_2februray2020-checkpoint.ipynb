# %%
import sys  
sys.path.insert(0, '/home/dfki/Desktop/Thesis/hyperopt')
import temp
import pickle

# %% [markdown]
# # 1000 iteration 0 initial point on My laptop

# %%
it1000_0in_timetracker_31 = pickle.load(open("/home/dfki/Desktop/Thesis/hyperopt/result_openml/mylaptop/31/1000it_0in_timetracker_31.p", "rb"))
it1000_0in_31 = pickle.load(open("/home/dfki/Desktop/Thesis/hyperopt/result_openml/mylaptop/31/1000it_0in_31.p", "rb"))


temp.time_tracker_plot(it1000_0in_timetracker_31, 'time', 'iteration', 'time(sec)}', show_plot=True)
temp.trial_utils(it1000_0in_31,0,1000)
# Out:
# total time point finding is 1428.9666149999998
# mean time for each configuration finding 1.4275390759240758
# Best score:0.7750000000000001
#  best score id:877
#  Average score[0,1000]:0.7281171497584542
#  number of all try: 1000
#  number of fail try:172
# -----------

# %% [markdown]
# # 1000 iteration 0 initial point on dima server

# %%
it1000_0 = pickle.load(open("/home/dfki/Desktop/Thesis/hyperopt/result_openml/result_onserver_openmlspace/31/1000it_0in_timetracker_31.p", "rb"))
temp.time_tracker_plot(it1000_0, 'time', 'iteration', 'time(sec)}', show_plot=True)

it1000_0_trial = pickle.load(open("/home/dfki/Desktop/Thesis/hyperopt/result_openml/result_onserver_openmlspace/31/1000it_0in_31.p", "rb"))
temp.trial_utils(it1000_0_trial,0,1000)
# Out:
# total time point finding is 2516.8193810000002
# mean time for each configuration finding 2.514305075924076
# Best score:0.779
#  best score id:790
#  Average score[0,1000]:0.7239212328767123
#  number of all try: 1000
#  number of fail try:124
# -----------

# %% [markdown]
# # 1000 iteration 1000 initial point on dima server

# %%
it1000_1000 = pickle.load(open("/home/dfki/Desktop/Thesis/hyperopt/result_openml/result_onserver_openmlspace/31/", "rb"))
temp.time_tracker_plot(it1000_1000, 'time', 'iteration', 'time(sec)}', show_plot=True)

it1000_1000_trial = pickle.load(open("/home/dfki/Desktop/Thesis/hyperopt/result_openml/result_onserver_openmlspace/31/", "rb"))
temp.trial_utils(it1000_1000_trial,0,1000)
